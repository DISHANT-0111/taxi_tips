# %% [markdown]
# **Dataset:**
# https://github.com/mwaskom/seaborn-data/blob/master/taxis.csv
#
# **Problem Statement:** Using the taxis dataset, develop a logistic regression model to predict whether a taxi trip included a tip - i.e., whether tip > 0.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df_taxi = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/taxis.csv")

# %%
df_taxi.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df_taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %% [markdown]
# Steps that I consider for Data-Cleaning :
# 1) Drop irrelevent columns. ['tolls' column]
# 2) Insert relevent columns. ['is tipped' column]
# 3) Manage Null records. ['mode' values]
# 4) Non-numeric Data types to Numeric. [datatype- object to boolean]

# %%
## The ultimate target(Title) of the Analysis.
df_taxi['is_tipped'] = df_taxi['tip'] > 0

# %%
df_taxi.drop('tolls', axis=1, inplace=True)

# %%
df_taxi.drop(['dropoff_zone', 'pickup_borough'],axis=1,inplace=True)

# %%
df_taxi.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    total   color      payment            pickup_zone dropoff_borough  \
# 0  12.95  yellow  credit card        Lenox Hill West       Manhattan
# 1   9.30  yellow         cash  Upper West Side South       Manhattan
# 2  14.16  yellow  credit card          Alphabet City       Manhattan
# 3  36.95  yellow  credit card              Hudson Sq       Manhattan
# 4  13.40  yellow  credit card           Midtown East       Manhattan
#
#    is_tipped
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True

# %%
#df_taxi['yellow'].value_counts()

# %%
yellow = pd.get_dummies(df_taxi['color'], drop_first=True)

df_taxi.drop('color', axis=1, inplace=True)

df_taxi = pd.concat([df_taxi, yellow], axis=1)

display(df_taxi.head())
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    total      payment            pickup_zone dropoff_borough  is_tipped  \
# 0  12.95  credit card        Lenox Hill West       Manhattan       True
# 1   9.30         cash  Upper West Side South       Manhattan      False
# 2  14.16  credit card          Alphabet City       Manhattan       True
# 3  36.95  credit card              Hudson Sq       Manhattan       True
# 4  13.40  credit card           Midtown East       Manhattan       True
#
#    yellow
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
#df_taxi['payment'].value_counts()

# %%
#df_taxi['payment'].isnull().sum()

# %%
cash = pd.get_dummies(df_taxi['payment'], drop_first=True)

df_taxi.drop('payment', axis=1, inplace=True)

df_taxi = pd.concat([df_taxi, cash], axis=1)

display(df_taxi.head())
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    total            pickup_zone dropoff_borough  is_tipped  yellow  \
# 0  12.95        Lenox Hill West       Manhattan       True    True
# 1   9.30  Upper West Side South       Manhattan      False    True
# 2  14.16          Alphabet City       Manhattan       True    True
# 3  36.95              Hudson Sq       Manhattan       True    True
# 4  13.40           Midtown East       Manhattan       True    True
#
#    credit card
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True

# %%
#df_taxi['pickup_zone'].value_counts()

# %%
#df_taxi['dropoff_borough'].value_counts()

# %%
# Check for null values in each column
null_counts = df_taxi.isnull().sum()
print("Null values in each column:")
display(null_counts[null_counts > 0])
# Out:
# Null values in each column:
# pickup_zone        26
# dropoff_borough    45
# dtype: int64

# %%
# Impute missing values in specified columns with the mode
cols_with_nulls = ['pickup_zone','dropoff_borough']

for col in cols_with_nulls:
    mode_val = df_taxi[col].mode()[0]
    df_taxi[col].fillna(mode_val, inplace=True)

# Verify that there are no more null values in these columns
print("Null values after imputation:")
display(df_taxi[cols_with_nulls].isnull().count())
# Out:
# Null values after imputation:
# /tmp/ipython-input-2194881597.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_taxi[col].fillna(mode_val, inplace=True)
# pickup_zone        6433
# dropoff_borough    6433
# dtype: int64

# %%
df_taxi.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    total            pickup_zone dropoff_borough  is_tipped  yellow  \
# 0  12.95        Lenox Hill West       Manhattan       True    True
# 1   9.30  Upper West Side South       Manhattan      False    True
# 2  14.16          Alphabet City       Manhattan       True    True
# 3  36.95              Hudson Sq       Manhattan       True    True
# 4  13.40           Midtown East       Manhattan       True    True
#
#    credit card
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True

# %%
## Convert 'pickup' and 'dropoff' to datetime objects
df_taxi['pickup'] = pd.to_datetime(df_taxi['pickup'])
df_taxi['dropoff'] = pd.to_datetime(df_taxi['dropoff'])

## Extract features from datetime columns

df_taxi['pickup_weeks'] = df_taxi['pickup'].dt.dayofweek
df_taxi['pickup_hours'] = df_taxi['pickup'].dt.hour

df_taxi['dropoff_weeks'] = df_taxi['dropoff'].dt.dayofweek
df_taxi['dropoff_hours'] = df_taxi['dropoff'].dt.hour

## Drop original datetime columns
df_taxi = df_taxi.drop(['pickup','dropoff'], axis=1)

# %%
df_taxi.head()
# Out:
#    passengers  distance  fare   tip  total            pickup_zone  \
# 0           1      1.60   7.0  2.15  12.95        Lenox Hill West
# 1           1      0.79   5.0  0.00   9.30  Upper West Side South
# 2           1      1.37   7.5  2.36  14.16          Alphabet City
# 3           1      7.70  27.0  6.15  36.95              Hudson Sq
# 4           3      2.16   9.0  1.10  13.40           Midtown East
#
#   dropoff_borough  is_tipped  yellow  credit card  pickup_weeks  pickup_hours  \
# 0       Manhattan       True    True         True             5            20
# 1       Manhattan      False    True        False             0            16
# 2       Manhattan       True    True         True             2            17
# 3       Manhattan       True    True         True             6             1
# 4       Manhattan       True    True         True             5            13
#
#    dropoff_weeks  dropoff_hours
# 0              5             20
# 1              0             16
# 2              2             18
# 3              6              1
# 4              5             13

# %%
df_taxi.drop(['pickup_zone', 'dropoff_borough'],axis=1,inplace=True)
df_taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   passengers     6433 non-null   int64
#  1   distance       6433 non-null   float64
#  2   fare           6433 non-null   float64
#  3   tip            6433 non-null   float64
#  4   total          6433 non-null   float64
#  5   is_tipped      6433 non-null   bool
#  6   yellow         6433 non-null   bool
#  7   credit card    6433 non-null   bool
#  8   pickup_weeks   6433 non-null   int32
#  9   pickup_hours   6433 non-null   int32
#  10  dropoff_weeks  6433 non-null   int32
#  11  dropoff_hours  6433 non-null   int32
# dtypes: bool(3), float64(4), int32(4), int64(1)
# memory usage: 370.8 KB

# %%
# Filter the correlation matrix to show correlations greater than 0.8 and display only True values
display(df_taxi.corr()[df_taxi.corr() > 0.8])
# Out:
#                passengers  distance      fare  tip     total  is_tipped  \
# passengers            1.0       NaN       NaN  NaN       NaN        NaN
# distance              NaN  1.000000  0.920108  NaN  0.904676        NaN
# fare                  NaN  0.920108  1.000000  NaN  0.974358        NaN
# tip                   NaN       NaN       NaN  1.0       NaN        NaN
# total                 NaN  0.904676  0.974358  NaN  1.000000        NaN
# is_tipped             NaN       NaN       NaN  NaN       NaN   1.000000
# yellow                NaN       NaN       NaN  NaN       NaN        NaN
# credit card           NaN       NaN       NaN  NaN       NaN   0.850457
# pickup_weeks          NaN       NaN       NaN  NaN       NaN        NaN
# pickup_hours          NaN       NaN       NaN  NaN       NaN        NaN
# dropoff_weeks         NaN       NaN       NaN  NaN       NaN        NaN
# dropoff_hours         NaN       NaN       NaN  NaN       NaN        NaN
#
#                yellow  credit card  pickup_weeks  pickup_hours  dropoff_weeks  \
# passengers        NaN          NaN           NaN           NaN            NaN
# distance          NaN          NaN           NaN           NaN            NaN
# fare              NaN          NaN           NaN           NaN            NaN
# tip               NaN          NaN           NaN           NaN            NaN
# total             NaN          NaN           NaN           NaN            NaN
# is_tipped         NaN     0.850457           NaN           NaN            NaN
# yellow            1.0          NaN           NaN           NaN            NaN
# credit card       NaN     1.000000           NaN           NaN            NaN
# pickup_weeks      NaN          NaN      1.000000           NaN       0.995235
# pickup_hours      NaN          NaN           NaN      1.000000            NaN
# dropoff_weeks     NaN          NaN      0.995235           NaN       1.000000
# dropoff_hours     NaN          NaN           NaN      0.941932            NaN
#
#                dropoff_hours
# passengers               NaN
# distance                 NaN
# fare                     NaN
# tip                      NaN
# total                    NaN
# is_tipped                NaN
# yellow                   NaN
# credit card              NaN
# pickup_weeks             NaN
# pickup_hours        0.941932
# dropoff_weeks            NaN
# dropoff_hours       1.000000

# %% [markdown]
# Analysis steps

# %%
from sklearn.model_selection import train_test_split # split data
from sklearn.linear_model import LogisticRegression  # Algorithm class
from sklearn.metrics import accuracy_score,confusion_matrix # Evaluation methods

# %%
x = df_taxi.drop('is_tipped',axis=1)
y = df_taxi['is_tipped']

# %%
 x.shape  # Table-Dimensions  >>  #(Rows,Columns) >> (output)
# Out:
# (6433, 11)

# %%
y.shape
# Out:
# (6433,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.25)

# %%
# create object
logr = LogisticRegression()

# train the model
logr.fit(x_train,y_train)

# predict values
y_pred = logr.predict(x_test)

# %%
accuracy_score(y_pred,y_test)*100  #(in percent)
# Out:
# 99.68924798011187

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 566,    5],
#        [   0, 1038]])
